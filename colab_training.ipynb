# %% [markdown]
# # 🚀 CRNN Model - Google Colab Training Runner
# This notebook clones your exact Python codebase from GitHub and executes it on a Free NVIDIA GPU.

# %% [markdown]
# ### Step 1: Clone your Repository & Install Dependencies
# This will pull your latest code (`train.py`, `data_generator.py`, etc.) directly from GitHub.

# %%
# !git clone https://github.com/ArnavJoshi75/Music-Recommendation-Engine.git
# %cd Music-Recommendation-Engine
# !pip install librosa

# %% [markdown]
# ### Step 2: Prepare the Dataset
# Your repository ignores the `Dataset/` folder, so we must download it directly to this Colab machine.
# *Note: It takes a few minutes to download and extract.*

# %%
import os
os.makedirs('Dataset', exist_ok=True)
# %cd Dataset

# Download metadata
# !wget -O fma_metadata.zip https://os.unil.cloud.switch.ch/fma/fma_metadata.zip
# !unzip -o fma_metadata.zip

# Download audio (FMA Small)
# !wget -O fma_small.zip https://os.unil.cloud.switch.ch/fma/fma_small.zip
# !unzip -o fma_small.zip

# Go back to project root
# %cd ..

# %% [markdown]
# ### Step 3: Run the Training Script!
# This will execute your `train.py` exactly as it runs on your local machine, but utilizing the Colab GPU.

# %%
# !python train.py

# %% [markdown]
# ### Step 4: Download your Trained Model
# Once training finishes (or if you stop it early and the callbacks save a model), run this to download the `.keras` file back to your physical computer.

# %%
from google.colab import files
files.download('best_crnn_model.keras')
